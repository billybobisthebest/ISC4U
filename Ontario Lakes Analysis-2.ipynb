# %% [markdown]
# # CSV Exercise
# - Bilal Rashid
# - Mr.Roberts
# - ICS4U
# - June 11th,2021

# %% [markdown]
# ## Part 1:
#
# Open the Excel file called “LakeOntarioSwimmers.xlsx” located in D2L, Unit 3, CSV Files and
# resave the file as a .csv format (comma delimited). Create a Python program that will read and
# display the contents of this file. Create filenames and variable names that suite the contents of
# the program (i.e. don’t just type my program and call your swimmer program BBQ).

# %%
import pandas as pd
## Opening the file using panadas
lake_ontario = pd.read_csv("Lake Ontario Swimmers-csv format-cleaned.csv")
## Printing the contents of file
whole_dataset = lake_ontario
whole_dataset
# Out:
#                       Name  Age       Date      Time
# 0             Marilyn Bell   16  08-Sep-54     20:55
# 1             John Jaremey   36  23-Jul-56     21:13
# 2            Brenda Fisher   28  12-Aug-56     18:51
# 3               Bill Sadlo   57  23-Aug-57  25:01:00
# 4                Jim Woods   41  26-Aug-57     18:35
# 5                Jim Woods   45  02-Sep-61     17:07
# 6           Cindy Nicholas   16  17-Aug-74     15:10
# 7               Diana Nyad   24  30-Aug-74     18:15
# 8             Debbie Roach   17  16-Aug-75     18:30
# 9           Angela Kondrak   17  22-Aug-76     23:48
# 10             Kim Lumsdon   19  27-Aug-76     21:27
# 11           John Kinsella   25  16-Aug-78     13:49
# 12            Claudio Plit   23  16-Aug-78     15:01
# 13         Raul Villagomez   27  16-Aug-78     15:09
# 14           Magdy Mandour   23  16-Aug-78     15:19
# 15              Bill Heiss   26  16-Aug-78     15:57
# 16        Loreen Passfield   21  01-Sep-79     15:43
# ...

# %%
## Assign specific variable to specific columns

## The "name" column and printhing only the first 2 rows of the "name" column
name = lake_ontario.loc[:,"Name"].head(2)
name
# Out:
# 0    Marilyn Bell
# 1    John Jaremey
# Name: Name, dtype: object

# %%
## Assign specific variable to specific columns

## The "Age" column and printhing only the first 2 rows of the "Age" column
age = lake_ontario.loc[:,"Age"].head(2)
age
# Out:
# 0    16
# 1    36
# Name: Age, dtype: int64

# %%
## Assign specific variable to specific columns

## The "Date" column and printhing only the first 2 rows of the "Date" column
date = lake_ontario.loc[:,"Date"].head(2)
date
# Out:
# 0    08-Sep-54
# 1    23-Jul-56
# Name: Date, dtype: object

# %%
## Assign specific variable to specific columns

## The "Time" column and printhing only the first 2 rows of the "Time" column
time = lake_ontario.loc[:,"Time"].head(2)
time
# Out:
# 0    20:55
# 1    21:13
# Name: Time, dtype: object

# %% [markdown]
# ## Part 2:
#
# Follow the handout called “StatsCanada Download Steps”. You can choose the same topic that I
# selected

# %%
from csv import reader

opened_file = open("population_stats_canada.csv")
read_file = reader(opened_file)
statscan = list(read_file)
## Printing all the rows
print(statscan)
# Out:
# [['\ufeff"Population estimates on July 1st', ' by age and sex" 1 2 3 4'], ['Annual'], ['Table: 17-10-0005-01 (formerly CANSIM 051-0001)'], ['Geography: Canada, Province or territory'], [], ['', 'Canada', '', '', '', ''], ['', 'Both sexes', '', '', '', ''], ['Age group 3 5', '2016', '2017', '2018', '2019', '2020'], ['', 'Persons', '', '', '', ''], ['All ages', '36,109,487', '36,545,295', '37,065,178', '37,593,384', '38,005,238'], ['0 to 4 years', '1,942,791', '1,941,873', '1,940,561', '1,932,463', '1,921,944'], ['5 to 9 years', '2,003,223', '2,021,564', '2,033,313', '2,041,032', '2,044,603'], ['10 to 14 years', '1,919,810', '1,948,681', '1,992,389', '2,032,988', '2,072,100'], ['15 to 19 years', '2,083,843', '2,090,598', '2,106,395', '2,114,539', '2,100,865'], ['20 to 24 years', '2,387,191', '2,401,419', '2,436,459', '2,475,546', '2,482,802'], ['25 to 29 years', '2,466,106', '2,513,657', '2,575,089', '2,626,058', '2,645,240'], ['30 to 34 years', '2,488,660', '2,515,087', '2,553,299', '
# ...
